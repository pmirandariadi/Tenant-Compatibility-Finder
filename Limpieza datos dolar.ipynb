# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import os
# %matplotlib inline

# %%
df = pd.read_csv("Dolar 2023.csv", delimiter = ";")

# %%
df
# Out:
#          Día     Ene     Feb     Mar  Abr  May  Jun  Jul  Ago  Sep  Oct  Nov  \
# 0          1     NaN  804,28  829,97  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1          2     NaN  791,80  815,24  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2          3  855,86  781,49  814,56  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3          4  852,14     NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4          5  855,10     NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5          6  856,31  788,88  808,91  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6          7     NaN  804,79  803,00  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 7          8     NaN  799,46  798,18  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8          9  846,38  793,19  802,88  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9         10  837,19  796,27  800,88  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10        11  833,73     NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
df = df.drop(df.index[31])

# %%
df.tail(2)
# Out:
#    Día     Ene  Feb     Mar  Abr  May  Jun  Jul  Ago  Sep  Oct  Nov  Dic
# 29  30  803,14  NaN  792,18  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30  31  810,37  NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
df_melted = pd.melt(df, id_vars=['Día'], value_vars=['Ene', 'Feb', 'Mar', 'Abr', 'May','Jun','Jul','Ago','Sep','Oct','Nov','Dic'], var_name='mes', value_name='valor_dolar')

# %%
#df_melted = df.melt(id_vars=['Día'], value_vars=['Ene', 'Feb', 'Mar', 'Abr', 'May','Jun','Jul','Ago','Sep','Oct','Nov','Dic'], var_name='mes', value_name='valor_dolar')
# Out:
# C:\Users\NACHOM~1\AppData\Local\Temp/ipykernel_17828/2407769496.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   df_melted = df.melt(id_vars=['Día'], value_vars=['Ene', 'Feb', 'Mar', 'Abr', 'May','Jun','Jul','Ago','Sep','Oct','Nov','Dic'], var_name='mes', value_name='valor_dolar')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\NACHOM~1\AppData\Local\Temp/ipykernel_17828/2407769496.py in <module>
# ----> 1 df_melted = df.melt(id_vars=['Día'], value_vars=['Ene', 'Feb', 'Mar', 'Abr', 'May','Jun','Jul','Ago','Sep','Oct','Nov','Dic'], var_name='mes', value_name='valor_dolar')
#
# ...

# %%
df_melted.head(60)
# Out:
#    Día  mes valor_dolar
# 0    1  Ene         NaN
# 1    2  Ene         NaN
# 2    3  Ene      855,86
# 3    4  Ene      852,14
# 4    5  Ene      855,10
# 5    6  Ene      856,31
# 6    7  Ene         NaN
# 7    8  Ene         NaN
# 8    9  Ene      846,38
# 9   10  Ene      837,19
# 10  11  Ene      833,73
# 11  12  Ene      825,67
# 12  13  Ene      822,32
# 13  14  Ene         NaN
# 14  15  Ene         NaN
# 15  16  Ene      824,33
# 16  17  Ene      821,59
# 17  18  Ene      820,89
# 18  19  Ene      812,45
# 19  20  Ene      828,74
# 20  21  Ene         NaN
# 21  22  Ene         NaN
# 22  23  Ene      821,02
# 23  24  Ene      814,11
# 24  25  Ene      805,45
# 25  26  Ene      803,68
# 26  27  Ene      802,58
# 27  28  Ene         NaN
# 28  29  Ene         NaN
# 29  30  Ene      803,14
# 30  31  Ene      810,37
# 31   1  Feb      804,28
# 32   2  Feb      791,80
# 33   3  Feb      781,49
# 34   4  Feb         NaN
# 35   5  Feb         NaN
# 36   6  Feb      788,88
# ...

# %%
df_melted["mes"].value_counts()
# Out:
# Ene    31
# Feb    31
# Mar    31
# Abr    31
# May    31
# Jun    31
# Jul    31
# Ago    31
# Sep    31
# Oct    31
# Nov    31
# Dic    31
# Name: mes, dtype: int64

# %%
#reemplazo = {"Ene":1, "Feb":2, "Mar":3, "Abr":4, "May":5,
#"Jun":6, "Jul":7, "Ago":8, "Sep":9, "Oct":10, "Nov":11, "Dic":12}

reemplazo = {"Ene":"Jan", "Feb":"Feb", "Mar":"Mar", "Abr":"Apr", "May":"May",
"Jun":"Jun", "Jul":"Jul", "Ago":"Aug", "Sep":"Sep", "Oct":"Oct", "Nov":"Nov", "Dic":"Dec"}

df_melted["mes"].replace(reemplazo, inplace=True)
df_melted
# Out:
#     Día  mes valor_dolar
# 0     1  Jan         NaN
# 1     2  Jan         NaN
# 2     3  Jan      855,86
# 3     4  Jan      852,14
# 4     5  Jan      855,10
# ..   ..  ...         ...
# 367  27  Dec         NaN
# 368  28  Dec         NaN
# 369  29  Dec         NaN
# 370  30  Dec         NaN
# 371  31  Dec         NaN
#
# [372 rows x 3 columns]

# %%
df_melted['fecha'] = df_melted['mes'].astype(str) + '/' + df_melted['Día'].astype(str) + '/2023'

# %%
df_melted.head(62)
# Out:
#    Día  mes valor_dolar        fecha
# 0    1  Jan         NaN   Jan/1/2023
# 1    2  Jan         NaN   Jan/2/2023
# 2    3  Jan      855,86   Jan/3/2023
# 3    4  Jan      852,14   Jan/4/2023
# 4    5  Jan      855,10   Jan/5/2023
# ..  ..  ...         ...          ...
# 57  27  Feb      818,67  Feb/27/2023
# 58  28  Feb      831,24  Feb/28/2023
# 59  29  Feb         NaN  Feb/29/2023
# 60  30  Feb         NaN  Feb/30/2023
# 61  31  Feb         NaN  Feb/31/2023
#
# [62 rows x 4 columns]

# %%
df_melted["mes"].value_counts()
# Out:
# Jan    31
# Feb    31
# Mar    31
# Apr    31
# May    31
# Jun    31
# Jul    31
# Aug    31
# Sep    31
# Oct    31
# Nov    31
# Dec    31
# Name: mes, dtype: int64

# %%
pd.isnull(df_melted["valor_dolar"]).values.ravel().sum()
# Out:
# 309

# %%
len(df_melted["valor_dolar"])
# Out:
# 372

# %%
df_melted = df_melted.drop(["Día","mes"], axis = 1)

# %%
df_melted.head(62)
# Out:
#    valor_dolar        fecha
# 0          NaN   Jan/1/2023
# 1          NaN   Jan/2/2023
# 2       855,86   Jan/3/2023
# 3       852,14   Jan/4/2023
# 4       855,10   Jan/5/2023
# ..         ...          ...
# 57      818,67  Feb/27/2023
# 58      831,24  Feb/28/2023
# 59         NaN  Feb/29/2023
# 60         NaN  Feb/30/2023
# 61         NaN  Feb/31/2023
#
# [62 rows x 2 columns]

# %%
df_melted = df_melted[['fecha','valor_dolar']]
df_melted
# Out:
#            fecha valor_dolar
# 0     Jan/1/2023         NaN
# 1     Jan/2/2023         NaN
# 2     Jan/3/2023      855,86
# 3     Jan/4/2023      852,14
# 4     Jan/5/2023      855,10
# ..           ...         ...
# 367  Dec/27/2023         NaN
# 368  Dec/28/2023         NaN
# 369  Dec/29/2023         NaN
# 370  Dec/30/2023         NaN
# 371  Dec/31/2023         NaN
#
# [372 rows x 2 columns]

# %%
df_melted = df_melted.stack().str.replace(',','.').unstack()

# %%
df_melted["valor_dolar"].notna().values.ravel().sum()
# Out:
# 63

# %%
df_melted.head(3)
# Out:
#         fecha valor_dolar
# 0  Jan/1/2023         NaN
# 1  Jan/2/2023         NaN
# 2  Jan/3/2023      855.86

# %%
df_melted = df_melted.dropna()

# %%
df_melted.head(3)
# Out:
#         fecha valor_dolar
# 2  Jan/3/2023      855.86
# 3  Jan/4/2023      852.14
# 4  Jan/5/2023      855.10

# %%
df_melted["valor_dolar"] = df_melted["valor_dolar"].astype("float64")
# Out:
# C:\Users\NACHOM~1\AppData\Local\Temp/ipykernel_17828/1368521820.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_melted["valor_dolar"] = df_melted["valor_dolar"].astype("float64")

# %%
df_melted.dtypes
# Out:
# fecha           object
# valor_dolar    float64
# dtype: object

# %%
df_melted["fecha"] = pd.to_datetime(df_melted["fecha"], format="%b/%d/%Y")
# Out:
# C:\Users\NACHOM~1\AppData\Local\Temp/ipykernel_17828/4277439511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_melted["fecha"] = pd.to_datetime(df_melted["fecha"], format="%b/%d/%Y")

# %%
df_melted
# Out:
#         fecha  valor_dolar
# 2  2023-01-03       855.86
# 3  2023-01-04       852.14
# 4  2023-01-05       855.10
# 5  2023-01-06       856.31
# 8  2023-01-09       846.38
# ..        ...          ...
# 85 2023-03-24       805.23
# 88 2023-03-27       811.48
# 89 2023-03-28       806.58
# 90 2023-03-29       799.76
# 91 2023-03-30       792.18
#
# [63 rows x 2 columns]

# %%
plt.plot(df_melted["fecha"], df_melted["valor_dolar"])

# %% [markdown]
# ## Limpieza para todos los archivos de datos

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'Detección de fraude tarjetas de credito',
#  'Dolar 2016.csv',
#  'Dolar 2017.csv',
#  'Dolar 2018.csv',
#  'Dolar 2019.csv',
#  'Dolar 2020.csv',
#  'Dolar 2021.csv',
#  'Dolar 2022.csv',
#  'Dolar 2023.csv',
#  'Gradient Descent',
#  'Limpieza datos dolar.ipynb',
#  'Limpieza y  Semantic Search For Beginners!',
#  'Pronóstico series temporales de LSTM',
#  'Proyecto corredores maraton Regresión Lineal',
#  'Prueba Limpieza para todos los archivos de datos.ipynb',
#  'PythonApplication1',
#  'Serie temporal ARIMA',
#  'Untitled1.ipynb']

# %%
archivos = [ 'Dolar 2016.csv',
 'Dolar 2017.csv',
 'Dolar 2018.csv',
 'Dolar 2019.csv',
 'Dolar 2020.csv',
 'Dolar 2021.csv',
 'Dolar 2022.csv',
 'Dolar 2023.csv']

# %% [markdown]
# ## Arreglar, no funciona

# %%
dataframes = []


for archivo in archivos:
    data = pd.read_csv(archivo, delimiter = ";")

    data = data.drop(data.index[31])
    data = pd.melt(data, id_vars=['Día'], value_vars=['Ene', 'Feb', 'Mar', 'Abr', 'May','Jun','Jul','Ago','Sep','Oct','Nov','Dic'], 
                   var_name='mes', value_name='valor_dolar')
    reemplazo = {"Ene":"Jan", "Feb":"Feb", "Mar":"Mar", "Abr":"Apr", "May":"May",
"Jun":"Jun", "Jul":"Jul", "Ago":"Aug", "Sep":"Sep", "Oct":"Oct", "Nov":"Nov", "Dic":"Dec"}
    data["mes"].replace(reemplazo, inplace=True)
    data['fecha'] = data['mes'].astype(str) + '/' + data['Día'].astype(str) + '/2023'
    data = data.drop(["Día","mes"], axis = 1)
    data = data[['fecha','valor_dolar']]
    data = data.stack().str.replace(',','.').unstack()
    data = data.dropna()
    data["valor_dolar"] = data["valor_dolar"].astype("float64")
    data["fecha"] = pd.to_datetime(data["fecha"], format="%b/%d/%Y")
    

    dataframes.append(data)

data_concatenado = pd.concat(dataframes)

plt.plot(data_concatenado["fecha"], data_concatenado["valor_dolar"])

plt.xlabel("Fecha")
plt.ylabel("Valor del dólar")
plt.title("Valor del dólar en el tiempo (todos los archivos)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# C:\Anaconda\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\NACHOM~1\AppData\Local\Temp/ipykernel_17828/1191233064.py in <module>
#      17     data = data.dropna()
# ...

# %% [markdown]
# ## Prueba de codigo

# %%
 
    data = pd.read_csv("Dolar 2018.csv", delimiter = ";")

    data = data.drop(data.index[31])
    data = pd.melt(data, id_vars=['Día'], value_vars=['Ene', 'Feb', 'Mar', 'Abr', 'May','Jun','Jul','Ago','Sep','Oct','Nov','Dic'], 
                   var_name='mes', value_name='valor_dolar')
    reemplazo = {"Ene":"Jan", "Feb":"Feb", "Mar":"Mar", "Abr":"Apr", "May":"May",
"Jun":"Jun", "Jul":"Jul", "Ago":"Aug", "Sep":"Sep", "Oct":"Oct", "Nov":"Nov", "Dic":"Dec"}
    data["mes"].replace(reemplazo, inplace=True)
    data['fecha'] = data['mes'].astype(str) + '/' + data['Día'].astype(str) + '/2023'
    data = data.drop(["Día","mes"], axis = 1)
    data = data[['fecha','valor_dolar']]
    data = data.stack().str.replace(',','.').unstack()
    data = data.dropna()
    data["valor_dolar"] = data["valor_dolar"].astype("float64")
    data["fecha"] = pd.to_datetime(data["fecha"], format="%b/%d/%Y")
    data
# Out:
#          fecha  valor_dolar
# 1   2023-01-02       614.75
# 2   2023-01-03       609.49
# 3   2023-01-04       604.84
# 4   2023-01-05       604.00
# 7   2023-01-08       606.04
# ..         ...          ...
# 361 2023-12-21       688.11
# 364 2023-12-24       691.87
# 366 2023-12-26       692.69
# 367 2023-12-27       693.78
# 368 2023-12-28       695.69
#
# [246 rows x 2 columns]
